# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1303/Cancer-Detection/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8d637c7-871e-41fc-bd68-2e8bc9e1761c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8d637c7-871e-41fc-bd68-2e8bc9e1761c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv('cancer.csv')
dataset.tail()
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  symmetry_mean  ...  radius_worst  texture_worst  \
# 564              0.13890         0.1726  ...        25.450          26.40
# ...

# %%
# Separate features (x) and target variable (y)
x = dataset.drop(columns=["diagnosis(1=m, 0=b)"])
y = dataset["diagnosis(1=m, 0=b)"]

# %%
# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# Build the model
model = tf.keras.models.Sequential()

# %%
# Input layer with the correct input shape
model.add(tf.keras.layers.Dense(256, input_shape=(30,), activation='sigmoid'))
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(x_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 1s 4ms/step - loss: 0.5845 - accuracy: 0.7099
# Epoch 2/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8989
# Epoch 3/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2811 - accuracy: 0.9121
# Epoch 4/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2384 - accuracy: 0.9165
# Epoch 5/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2233 - accuracy: 0.9143
# Epoch 6/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2315 - accuracy: 0.9209
# Epoch 7/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1981 - accuracy: 0.9231
# Epoch 8/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2332 - accuracy: 0.9231
# Epoch 9/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.9275
# Epoch 10/1000
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1286 - accuracy: 0.9474
# [0.1286124289035797, 0.9473684430122375]
